# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://www.kerjausaha.com/wp-content/uploads/2019/09/kucing-jantan.jpg",
        ]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Melihat ukuran file image
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  762  x  1080
# <PIL.Image.Image image mode=RGB size=1080x762 at 0x7F2626B90670>

# %%
# Mengakses pixel dengan memberi garis diagonal menyilang
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=2160x762 at 0x7F267450E9A0>

# %%
# GARIS VERTIKAL dan DIAGONAL
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# membuat garis diagonal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

line1_1 = (0,0)
line1_2 = (640,360)

line2_1 = (1020,0)
line2_2 = (-360,1020)

cv.line(image_3, line1_1, line1_2, (255,255,255))
cv.line(image_3, line2_1, line2_2, (255,255,255))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# PERTANYAAN
#
# **1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?**
# Google COllabs memudahkan pengguna dalam melakukan pemrograman menggunakan python , karena tidak perlu menginstall software, library dsb. kemudian juga memudahkan pengguna dalam proses eksekusi program di browser.
#
# **2.Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?**
# Untuk apakah semua library dibawah ini digunakan semua jawabannya adalah tidak, karena ada beberapa library yang memiliki fungsi sama.
#
# Numpy (Numerical Python): Numpy adalah library untuk memproses data numerik dan matematika pada Python. Fungsinya meliputi operasi matematika, pengolahan matriks, dan pemrosesan data statistik.
#
# Pandas: Pandas adalah library untuk manipulasi dan analisis data. Fungsinya meliputi pemrosesan data tabel, pengolahan data missing, penggabungan data, dan pengolahan data time-series.
#
# OpenCV (Open Source Computer Vision Library): OpenCV adalah library untuk computer vision dan pengolahan gambar. Fungsinya meliputi operasi pengolahan gambar, deteksi objek, tracking objek, dan analisis warna gambar.
#
# Scikit-image (Scikit-image Scientific Image Processing Library): Scikit-image adalah library untuk pengolahan gambar dan computer vision. Fungsinya meliputi operasi pengolahan gambar, deteksi tepi, pembersihan noise, dan segmentasi gambar.
#
# PIL (Python Imaging Library): PIL adalah library untuk pengolahan gambar. Fungsinya meliputi operasi pengolahan gambar, konversi format gambar, dan manipulasi gambar.
#
# Matplotlib: Matplotlib adalah library untuk plotting dan visualisasi data. Fungsinya meliputi plotting data, membuat histogram, diagram batang, dan scatter plot.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut : ![image.png](data:image/png;base64,...)Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
#
# Kegunaan dari code tersebut adalah meresize gambar menjadi setengah dari resolusi awal , dimana pada gambar diatas adalah awalnya mempunyai ukuran 1523x2160 di resize menjadi 762x1080. pengaruh jika tidak menggunakan kode ini maka ukuran dari gambar tersebut akan tetap pada 1523x2160.
#
# 4. Apakah kegunaan kode [255,255,255] ? Jelaskan! kegunaan kode tersebut adalah kode warna Putih . dimana kode warna putih ini digunakan untuk membuat sebuah garis horizontal ditengah image . warna putih ini didapat dari mengubah nilai RGB menjadi (255,255,255) , jika ingin membuat warna hitam maka  nilai 255 bisa diganti dengan 0
#
# 5.Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Pixel adalah unit dasar dalam pengolahan gambar digital, dan resolusi adalah jumlah pixel yang digunakan untuk menggambarkan sebuah gambar. Keterkaitan antara kedua hal ini adalah semakin tinggi resolusi sebuah gambar, semakin banyak pixel yang digunakan untuk menggambarkan gambar, sehingga gambar terlihat lebih jelas dan tajam. Sebaliknya, jika resolusi gambar rendah, jumlah pixel yang digunakan juga rendah, sehingga gambar akan terlihat kurang jelas dan kasar.
