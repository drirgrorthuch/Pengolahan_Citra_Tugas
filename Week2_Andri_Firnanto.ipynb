# %% [markdown]
# **Tugas Pengolahan Citra Minggu KE-2**
#
# **Andri Firnanto**
#
# **NIM 200536626424**

# %%
from google.colab import drive


# Accessing my google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/masbro.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/masbro.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
#inisialisasi numpy array dengan type data int32
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
#reshape array
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
#penambahan polyline pada black image kedua
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# PERTANYAAN
#
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
#
# 3. Jelaskan tentang angka-angka yang terdapat pada reshape((-1,1,2))
#
# 4. Apakah kegunaan "google.colab.patches import cv2_imshow"
#
# 5. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 4

# %% [markdown]
# JAWABAN
#
# 1.Perbedaannya terletak pada penyajian gambar nya, jika menggunakan matplotlib gambar disajikan dengan menggunakan plot dan di resize disesuaikan plot namun memakai format BGR (Blue Green Red) menjadikan warna awalnya kebiruan. jika tidak memakai matplotlib maka gambar akan disajikan secara mentah(plot) sesuai dengan gambar asli mulai dari ukuran sampai warnanya.
# ![week2_jawaban1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2.Perbedaannya terdapat pada jumlah bit yang dipakai. jumlah bit yang dipakai ini mempengaruhi besarnya kapasitas data yang bisa ditampung. untuk perbedaan pada gambar tidak terlihat namun untuk nilai hexanya berbeda
# ![week2_jawaban2.jpg](data:image/jpeg;base64,...)
#
# 3. Perintah ini memiliki fungsi untuk mengubah bentuk array yang ada menjadi array baru dengan dimensi (x,1,2), dimana jumlah baris dalam array baru akan ditentukan oleh Numpy dan ukuran pada sumbu ketiga dan keempat adalah 1 dan 2. Ini sangat berguna ketika kita ingin mengubah bentuk array agar sesuai dengan kebutuhan kita, seperti mengubah bentuk dari (x,y) menjadi (x,1,y) atau sebaliknya.
#
# 4. Dalam hal ini kita mengimpor sebuah fungsi dari paket google collab berupa cv2_imgshow agar bisa dipakai dalam program, fungsi cv2_imgshow sendiri adalah fungsi menampilkan gambar dalam environment google collab ini sendiri.
#
# 5. potongan kode ini digunakan untuk mengimpor modul io dari library skimage . modul io sendiri berfungsi sebagai reader dan writer gambar dari dan ke dalam format file apapun. dalam modul ini terdapat berbagai fungsi misal imshow yang berfungsi untuk menampilkan gambar, imsave untuk menyimpan gambar, dan imread untuk membaca gambar dari file.

# %% [markdown]
# Dibawah ini adalah bagian pengerjaan Tugas Praktikum

# %%
#no 1 (menampilkan gambar hanya dalam channel R-G dan G-B saja)
#Red-Green
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,2] = 0
plt.imshow(img3)

# %%
#Green-Blue
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,0] = 0
plt.imshow(img3)

# %%
#no 2 (menampilkan image baris ke 10-100, kolom 10-100)
plt.imshow(img[10:100, 10:100])

# %%
#no 3(image baris ke 5-30, semua kolom, channel Green saja)

img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,2)] = 0
plt.imshow(img3[5:30])

# %%
#no 4 (Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image. )
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img3,pt1=(150,850),pt2=(920,1020),color=(255,0,0),thickness=10)
cv.rectangle(img3,pt1=(300,300),pt2=(420,400),color=(0,255,0),thickness=10)
cv.rectangle(img3,pt1=(450,350),pt2=(580,480),color=(0,0,255),thickness=10)
cv.rectangle(img3,pt1=(650,350),pt2=(780,500),color=(0,255,255),thickness=10)
cv.rectangle(img3,pt1=(800,650),pt2=(200,200),color=(255,255,255),thickness=10)
plt.imshow(img3)

# %%
#no 5 (menampilkan gambar dalam keadaan terbalik)
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(4,4))   #ubah sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
#no 6 (Buat rectangle dan circle pada bagian wajah dari image kitten saya ganti dgn capybara!)
img = cv.imread('/content/drive/MyDrive/PCVK/masbro.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.circle(img3, (525,400),300, (255,0,0), 5)
cv.rectangle(img3,pt1=(300,200),pt2=(750,580),color=(0,255,0),thickness=10)
plt.imshow(img3)

# %%
#No 7 (Buat rectangle pada sudut bawah kiri channel B pada color space RGB dari citra masbro.jpg!)
img = cv.imread('/content/drive/MyDrive/PCVK/masbro.jpg')
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
img3[:,:,(0,1)] = 0
cv.rectangle(img3,pt1=(0,1040),pt2=(140,900),color=(0,255,0),thickness=10)
plt.imshow(img3)

# %% [markdown]
# ### **Selesai**
